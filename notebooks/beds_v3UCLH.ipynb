# %% [markdown]
# - 2022-07-03
# - working notes on merging caboodle info on beds with EMAP
# - aim is to build a reliable view of bed census
# - programmatically returns a list of locatoins with Caboodle detail
# - but no testing/quality control
# - works in conjunction with add_caboodle2emap_beds.py
# - use to populate base bed definitions for the tower flow

# %% [markdown]
# ## Set-up incl database connections

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import urllib

from pathlib import Path
from sqlalchemy import create_engine
from sqlalchemy.engine import Engine

# %%
def emap_db() -> Engine:
    url = "postgresql+psycopg2://{}:{}@{}:{}/{}".format(
        os.getenv('EMAP_DB_USER'),
        os.getenv('EMAP_DB_PASSWORD'),
        os.getenv('EMAP_DB_HOST'),
        os.getenv('EMAP_DB_PORT'),
        os.getenv('EMAP_DB_NAME'),
    )
    engine = create_engine(
        url, pool_size=4, max_overflow=6, connect_args={"connect_timeout": 120}
    )
    return engine

def caboodle_db() -> Engine:
    db_host = os.getenv('CABOODLE_DB_HOST')
    db_user = os.getenv('CABOODLE_DB_USER')
    db_password = os.getenv('CABOODLE_DB_PASSWORD')
    db_port = os.getenv('CABOODLE_DB_PORT')
    db_name = os.getenv('CABOODLE_DB_NAME')
    connection_str = f"mssql+pyodbc://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}?driver=ODBC+Driver+17+for+SQL+Server"
    engine = create_engine(connection_str)
    return engine

# %%
emap_engine = emap_db()
caboodle_engine = caboodle_db()

# %% [markdown]
# ## Reliable way of joining Caboodle and EMAP bed level data

# %% [markdown]
# First load EMAP location table into memory
#
# Do this with no modifications / transformations other than the join

# %%
q = """
SELECT 
    lo.location_id, lo.location_string, lo.department_id, lo.room_id, lo.bed_id, dept.name department, dept.speciality, room.name room
FROM star.location lo
LEFT JOIN star.department dept ON lo.department_id = dept.department_id
LEFT JOIN star.room ON lo.room_id = room.room_id
"""
dfe = pd.read_sql_query(q, emap_engine)
dfe.head()
# Out:
#    location_id            location_string  department_id  room_id  bed_id  \
# 0    332058773            JTL2A^null^null    332058774.0      NaN     NaN
# 1    332058795        SYSCOPATH^null^null    332058796.0      NaN     NaN
# 2         1160  ED^UCHED DIAGNOSTICS^NONE            NaN      NaN     NaN
# 3    332058799       1000000809^null^null    332058800.0      NaN     NaN
# 4    332058837            1TRDB^null^null    332058838.0      NaN     NaN
#
#            department                     speciality  room
# 0           UCH JTL2A      General Surgery - General  None
# 1   SYSTEM COPATH ERR                           None  None
# 2                None                           None  None
# 3  SYSTEM WINPATH ERR                           None  None
# 4           OUT 1TRDB  Audiology - Outreach Services  None

# %% [markdown]
# And load Caboodle DepartmentDim into memory

# %%
q = """
SELECT 
 DepartmentKey
,BedEpicId
,Name
,DepartmentName
,RoomName
,BedName
,IsBed
,BedInCensus
,IsDepartment
,IsRoom
,IsCareArea
,DepartmentExternalName
,DepartmentSpecialty
,DepartmentType
,DepartmentServiceGrouper
,DepartmentLevelOfCareGrouper
,LocationName
,ParentLocationName
,_CreationInstant
,_LastUpdatedInstant
FROM dbo.DepartmentDim
"""
dfc = pd.read_sql_query(q, caboodle_engine)
dfc.head()
# Out:
#    DepartmentKey        BedEpicId             Name          DepartmentName  \
# 0             -3         *Deleted         *Deleted                *Deleted
# 1             -2  *Not Applicable  *Not Applicable         *Not Applicable
# 2             -1     *Unspecified     *Unspecified            *Unspecified
# 3              1             1000             OR 3  EMH FS MATERNITY DLVRY
# 4              2             1001           RC02-A  EMSNF RESIDENTIAL CARE
#
#           RoomName          BedName  IsBed  BedInCensus  IsDepartment  IsRoom  \
# 0         *Deleted         *Deleted    NaN          NaN           NaN     NaN
# 1  *Not Applicable  *Not Applicable    NaN          NaN           NaN     NaN
# 2     *Unspecified     *Unspecified    NaN          NaN           NaN     NaN
# 3       L&D - OR 3             OR 3    1.0          1.0           0.0     0.0
# 4             RC02           RC02-A    1.0          1.0           0.0     0.0
#
#    IsCareArea  DepartmentExternalName                  DepartmentSpecialty  \
# 0         NaN                *Deleted                             *Deleted
# 1         NaN         *Not Applicable                      *Not Applicable
# 2         NaN            *Unspecified                         *Unspecified
# 3         0.0  EMH Labor and Delivery                    Maternity - Birth
# 4         0.0  EMSNF Residential Care  Transplant - Small Bowel Assessment
#
#                      DepartmentType DepartmentServiceGrouper  \
# 0                          *Deleted                 *Deleted
# 1                   *Not Applicable          *Not Applicable
# 2                      *Unspecified             *Unspecified
# 3                               L&D             *Unspecified
# 4  Rehabilitation / Continuing Care             *Unspecified
#
#   DepartmentLevelOfCareGrouper                  LocationName  \
# 0                     *Deleted                      *Deleted
# 1              *Not Applicable               *Not Applicable
# 2                 *Unspecified                  *Unspecified
# 3                 *Unspecified                  EHS HOSPITAL
# 4                 *Unspecified  EHS SKILLED NURSING FACILITY
#
#              ParentLocationName        _CreationInstant  \
# 0                      *Deleted                     NaT
# 1               *Not Applicable                     NaT
# 2                  *Unspecified                     NaT
# 3  EHS PARENT HOSPITAL LOCATION 2019-01-24 01:04:14.023
# 4  EHS SKILLED NURSING FACILITY 2019-01-24 01:04:14.023
#
#       _LastUpdatedInstant
# 0                     NaT
# 1                     NaT
# 2                     NaT
# 3 2022-06-08 17:06:26.993
# 4 2022-06-08 17:06:26.993

# %% [markdown]
# Now join these two tables
# - don't attempt joins where there is no room/bed level data (b/c they're not physical locations
# - you need a multi-key join
#     - EMAP 'name' (department.name) joins on to Caboodle 'DepartmentName'
#     - EMAP 'bed' (derived by splitting location.location_string) joins on to Caboodle 'Name'
# - drop 'wait' beds since these duplicate and block a one-to-one merge
# - try to be rigorous in `pd.merge`
#     - `indicator=True` to allow inspection post merge
#     - `validate='one_to_one'` to throw an error if duplicates found
#
# Note
# - sometimes (in Caboodle) DepartmentName and Name are duplicated so pick the most recently 'created'
#
# using ...

# %% [markdown]
# Now load external code

# %%
import importlib
import add_caboodle2emap_beds
importlib.reload(add_caboodle2emap_beds)
from add_caboodle2emap_beds import bed_merge

# %%
departments=[
# Built from Tower Report 14 Jun 2022
# NAME                         # n emap locations
"UCH T01 ACUTE MEDICAL",       # 86
"UCH T01 ENHANCED CARE",       # 20
"UCH T03 INTENSIVE CARE",      # 37
"UCH T10 SOUTH (T10S)",        # 34
"UCH T10 NORTH (T10N)",        # 32
"UCH T10 MED (T10M)",          # 16
"UCH T11 SOUTH (T11S)",        # 27
"UCH T11 NORTH (T11N)",        # 25
"UCH T11 EAST (T11E)",         # 16
"UCH T11 NORTH (T11NO)",       #  8
"UCH T12 SOUTH (T12S)",        # 32
"UCH T12 NORTH (T12N)",        # 23
"UCH T13 SOUTH (T13S)",        # 31
"UCH T13 NORTH ONCOLOGY",      # 26
"UCH T13 NORTH (T13N)",        # 26
"UCH T14 NORTH TRAUMA",        # 28
"UCH T14 NORTH (T14N)",        # 28
"UCH T14 SOUTH ASU",           # 22
"UCH T14 SOUTH (T14S)",        # 17
"UCH T15 SOUTH DECANT",        # 21
"UCH T15 SOUTH (T15S)",        # 21
"UCH T15 NORTH (T15N)",        # 16
"UCH T15 NORTH DECANT",        # 15
"UCH T16 NORTH (T16N)",        # 19
"UCH T16 SOUTH (T16S)",        # 18
"UCH T16 SOUTH WINTER",        # 17
"GWB L01 ELECTIVE SURG",       # 37
"GWB L01 CRITICAL CARE",       # 12
"GWB L02 NORTH (L02N)",        # 19
"GWB L02 EAST (L02E)",         # 19
"GWB L03 NORTH (L03N)",        # 19
"GWB L03 EAST (L03E)",         # 19
"GWB L04 NORTH (L04N)",        # 20
"GWB L04 EAST (L04E)",         # 17
"WMS W04 WARD",                # 28
"WMS W03 WARD",                # 27
"WMS W02 SHORT STAY",          # 20
"WMS W01 CRITICAL CARE",       # 11
]

# %%
dfm = bed_merge(df_emap=dfe, df_caboodle=dfc, departments=departments)
dfm.head()
# Out:
# 101     gynaecology - general __ uch t06 gynae (t06g) ...
# 102     oncology - acute oncology service __ uch t13 n...
# 104     oncology - acute oncology service __ uch t13 n...
# 155     oncology - acute oncology service __ uch t13 n...
# 157     oncology - acute oncology service __ uch t13 n...
#                               ...
# 8724    haematology - general __ gwb l04 east (l04e) _...
# 8729    haematology - general __ gwb l04 east (l04e) _...
# 8841    haematology - general __ gwb l04 east (l04e) _...
# 8844    haematology - general __ gwb l04 east (l04e) _...
# 8848    haematology - general __ gwb l04 north (l04n) ...
# Name: loc2merge, Length: 1206, dtype: object
# 31793    critical care - gwb l01 icu __ gwb l01 critica...
# 31794    critical care - gwb l01 icu __ gwb l01 critica...
# 31795    critical care - gwb l01 icu __ gwb l01 critica...
# 31796    critical care - gwb l01 icu __ gwb l01 critica...
# 31797    critical care - gwb l01 icu __ gwb l01 critica...
#                                ...
# 1631     thoracic surgery __ wms w04 ward __ sr20 __ sr...
# 1632     thoracic surgery __ wms w04 ward __ sr21 __ sr...
# 1626     thoracic surgery __ wms w04 ward __ sr22 __ sr...
# 1627     thoracic surgery __ wms w04 ward __ sr23 __ sr...
# 1633     thoracic surgery __ wms w04 ward __ sr24 __ sr...
# Name: loc2merge, Length: 1196, dtype: object
#    location_id                location_string  department_id      room_id  \
# 0    332107428     T06G^PATIENT LOUNGE^Lounge    331969463.0  332107429.0
# 1    332108405  1020100163^T13NO BY01^BY01-20    332108406.0  332108409.0
# 2    332108436  1020100163^T13NO SR01^SR01-01    332108406.0  332108437.0
# 3    332108443  1020100163^T13NO BY02^BY02-23    332108406.0  332108444.0
# 4    332108449  1020100163^T13NO BY02^BY02-25    332108406.0  332108444.0
#
#         bed_id              department                         speciality  \
# 0  332107431.0    UCH T06 GYNAE (T06G)              Gynaecology - General
# 1  332108411.0  UCH T13 NORTH ONCOLOGY  Oncology - Acute Oncology Service
# 2  332108439.0  UCH T13 NORTH ONCOLOGY  Oncology - Acute Oncology Service
# 3  332108446.0  UCH T13 NORTH ONCOLOGY  Oncology - Acute Oncology Service
# 4  332108450.0  UCH T13 NORTH ONCOLOGY  Oncology - Acute Oncology Service
#
#              room        dept        room_hl7  ...  \
# 0  Patient Lounge        T06G  PATIENT LOUNGE  ...
# 1            BY01  1020100163      T13NO BY01  ...
# 2            SR01  1020100163      T13NO SR01  ...
# 3            BY02  1020100163      T13NO BY02  ...
# 4            BY02  1020100163      T13NO BY02  ...
#
#                             DepartmentExternalName  \
# 0           UCH Tower 6th Floor Gynaecology (T06G)
# 1  UCH Tower 13th Floor North (T13N) Oncology Ward
# 2  UCH Tower 13th Floor North (T13N) Oncology Ward
# 3  UCH Tower 13th Floor North (T13N) Oncology Ward
# 4  UCH Tower 13th Floor North (T13N) Oncology Ward
#
#                  DepartmentSpecialty  DepartmentType DepartmentServiceGrouper  \
# 0              Gynaecology - General             HOD              Gynaecology
# 1  Oncology - Acute Oncology Service             HOD                 Oncology
# 2  Oncology - Acute Oncology Service             HOD                 Oncology
# 3  Oncology - Acute Oncology Service             HOD                 Oncology
# 4  Oncology - Acute Oncology Service             HOD                 Oncology
#
#   DepartmentLevelOfCareGrouper                        LocationName  \
# 0                     Surgical  UNIVERSITY COLLEGE HOSPITAL CAMPUS
# 1                       Cancer  UNIVERSITY COLLEGE HOSPITAL CAMPUS
# 2                       Cancer  UNIVERSITY COLLEGE HOSPITAL CAMPUS
# 3                       Cancer  UNIVERSITY COLLEGE HOSPITAL CAMPUS
# 4                       Cancer  UNIVERSITY COLLEGE HOSPITAL CAMPUS
#
#      ParentLocationName        _CreationInstant     _LastUpdatedInstant  \
# 0  UCLH PARENT HOSPITAL 2020-06-02 00:47:26.050 2022-06-08 17:06:26.993
# 1  UCLH PARENT HOSPITAL 2022-01-19 00:34:57.627 2022-06-08 17:06:26.993
# 2  UCLH PARENT HOSPITAL 2022-01-19 00:34:57.627 2022-06-08 17:06:26.993
# 3  UCLH PARENT HOSPITAL 2022-01-19 00:34:57.627 2022-06-08 17:06:26.993
# 4  UCLH PARENT HOSPITAL 2022-01-19 00:34:57.627 2022-06-08 17:06:26.993
#
#    _merge
# 0    both
# 1    both
# 2    both
# 3    both
# 4    both
#
# [5 rows x 33 columns]

# %%
dfm._merge.value_counts()
# Out:
# both          1120
# left_only       86
# right_only       0
# Name: _merge, dtype: int64

# %%
dfm.to_csv('beds.tsv', sep='\t', index_label='local_id')
