# %% [markdown]
# # Prepare synthetic data
# It is going to be much easier to develop if you have realistic synthetic data.
# Here we take a sql query that generates a single tabular output.
# We run that query against the live identifiable data once.
# We then use the [Synthetic Data Vault](https://sdv.dev/SDV/index.html) to prepare a synthetic model of those data.
# The code below serves as a vignette for that process but will need adjusting to match the exact contents of the original query.
#
# More complex examples that include multiple tables with joins and dependencies are also possible.
#
# This notebook should be run interactively just once

# %% [markdown]
# ## Set-up, query and return the data as datafame
# The query lives in `./src/api` where `.` represents the project root.
# If you run this JupyterNotebook using the local **Makefile** and `make run` then that query will be automatically copied here.
#
# So first steps should be (from _this_ directory)
# ```sh
# make build
# make run
# ```
# then navigate to http://uclvlddpragae07:8091/lab/tree/steve/work/synth_test_data.ipynb

# %%
import os
import pandas as pd

from pathlib import Path
from sqlalchemy import create_engine

# %%
# Construct the PostgreSQL connection
uds_host = os.getenv('UDS_HOST')
uds_user = os.getenv('UDS_USER')
uds_passwd = os.getenv('UDS_PWD')

emapdb_engine = create_engine(f'postgresql://{uds_user}:{uds_passwd}@{uds_host}:5432/uds')

# %%
# Read the sql file into a query 'q' and the query into a dataframe
q = Path('query.sql').read_text()
df = pd.read_sql_query(q, emapdb_engine)

# %%
df.head()

# %% [markdown]
# ## Generate a synthetic version of the real data
#
# Use the table above to generate the metadata you need for the synthetic data
#
# https://sdv.dev/SDV/user_guides/relational/relational_metadata.html#relational-metadata

# %%
# Minimal imports
from sdv import Metadata, SDV

# %%
# PostgreSQL returns datetimes with tz info which sdv does not seem to be able to handle
def remove_timezone(df, col_name: str) -> pd.DataFrame:
    """sdv does not like timezones"""
    df[col_name] = pd.to_datetime(df[col_name], utc=True).dt.tz_localize(None)    
    return df

# %% [markdown]
# ### Prepare data and metadata

# %%
tz_cols = ['valid_from', 'scheduled_datetime', 'status_change_time', 'admission_time', 'discharge_time']
for col in tz_cols:
    print(col)
    df = remove_timezone(df, col)
# Out:
# valid_from
# scheduled_datetime
# status_change_time
# admission_time
# discharge_time

# %% [markdown]
# sdv doesn't always recognise the columns correctly. Here we specify data_of_birth explicitly as a date.

# %%
fields = {
    'date_of_birth': {
        'type': 'datetime',
        'format': '%Y-%m-%d',
    }
}

# %% [markdown]
# Prepare the metadata

# %%
metadata = Metadata()
metadata.add_table(
    name='tabpid',
    data=df,
    fields_metadata=fields,
)

# %%
# Inspect the conversion that metadata.add_table did to the dataframe that you loaded
metadata.get_table_meta('tabpid')
# Out:
# {'fields': {'date_of_birth': {'type': 'datetime', 'format': '%Y-%m-%d'},
#   'firstname': {'type': 'categorical'},
#   'lastname': {'type': 'categorical'},
#   'mrn': {'type': 'categorical'},
#   'nhs_number': {'type': 'categorical'},
#   'valid_from': {'type': 'datetime'},
#   'comments': {'type': 'categorical'},
#   'scheduled_datetime': {'type': 'datetime'},
#   'status_change_time': {'type': 'datetime'},
#   'name': {'type': 'categorical'},
#   'admission_time': {'type': 'datetime'},
#   'discharge_time': {'type': 'datetime'},
#   'dept_name': {'type': 'categorical'},
#   'location_string': {'type': 'categorical'}}}

# %% [markdown]
# Prepare the table(s)

# %%
tables = dict(tabpid=df)

# %% [markdown]
# Fit the model

# %%
sdv = SDV()
sdv.fit(metadata, tables)

# %% [markdown]
# Inspect the original data

# %%
df.head()

# %% [markdown]
# Inspect the synthetic data

# %%
sdv.sample_all()['tabpid'].head()
# Out:
#   date_of_birth  firstname lastname       mrn  nhs_number          valid_from  \
# 0    1956-04-30    JEFFERY  HAYFORD  21368822  4283098787 2021-11-05 07:57:34
# 1    1974-11-25     MARION   BUTLER  21056762  6288467669 2022-03-06 16:30:20
# 2    1945-02-06  CHRISTINA  GUNNELL  41644720  6324283089 2022-01-30 23:35:06
# 3    1949-01-31   KUNVERJI    CHINN  03080886  4660936740 2022-04-02 07:23:52
# 4    1934-02-27      AHMED     HALL  U/EZ1177  4683480654 2022-06-24 13:32:58
#
#   comments  scheduled_datetime  status_change_time  \
# 0      NaN 2020-06-07 14:55:00 2021-11-05 09:39:28
# 1      NaN 2022-07-22 14:25:00 2022-03-06 15:58:01
# 2      NaN 2021-11-30 06:27:00 2022-01-31 00:53:52
# 3      NaN 2022-12-20 15:22:00 2022-04-02 07:16:06
# 4      NaN 2022-10-27 19:05:00 2022-06-24 15:16:10
#
#                                               name      admission_time  \
# 0                  Inpatient consult to Obstetrics 2020-06-19 00:22:14
# 1                   Inpatient consult to Neurology 2022-08-28 04:32:15
# 2   Inpatient consult to Dietetics (N&D) - Not TPN 2021-12-11 22:13:27
# 3              Inpatient consult to Acute Medicine 2022-12-17 17:32:05
# 4  Inpatient consult to Mental Health Liaison Team 2022-10-30 19:06:16
#
#   discharge_time               dept_name             location_string
# 0            NaT    GWB L02 NORTH (L02N)  ED^UCHED PAEDS TRIAGE^NONE
# 1            NaT      UCH EMERGENCY DEPT     WSU3^W03W BY04^BY04-315
# 2            NaT    UCH T14 NORTH TRAUMA     LYNQ^Q1LAA SR02^SR02-02
# 3            NaT  UCH T13 NORTH ONCOLOGY        null^SDEC 18^18 SDEC
# 4            NaT                UCH SDEC  1020100166^SDEC 19^19 SDEC

# %% [markdown]
# ### Save the synthetic data
#
# Options
# - save the model and not the synthetic data (but then you need *sdv* to run the model)
# - save the data (need some care with type conversions if you use csv etc.)

# %%
sdv.save('sdv_model.pkl')

# %%
sample = sdv.sample_all()
sample_df = sample['tabpid']
sample_df.to_hdf('sample_df.hdf', 'data')
# Out:
# /tmp/ipykernel_3877/2363807172.py:3: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['firstname', 'lastname', 'mrn', 'nhs_number', 'comments', 'name',
#        'dept_name', 'location_string'],
#       dtype='object')]
#
#   sample_df.to_hdf('sample_df.hdf', 'data')

# %%
pd.read_hdf('sample_df.hdf', 'data')
# Out:
#      date_of_birth  firstname     lastname       mrn  nhs_number  \
# 0       2003-05-06      RAZAN    AL-KUWARI  21495267  4808270676
# 1       1944-09-20    SHIRLEY    MEKOLLARI  91079225  4821915790
# 2       1963-04-05      MARIA      SINNOTT  21491112  4430676615
# 3       1961-02-19    LORENZO       CABRAL  94045562  4828721452
# 4       1955-07-27  CHRISTINE     PONSFORD  40316701  4467251227
# ...            ...        ...          ...       ...         ...
# 1554    1977-03-01       EMMA      CORDARA  M/288957  6249600760
# 1555    1954-04-22      JAMES  OLAFSDOTTIR  21457472  7268522452
# 1556    1970-03-03     AINHOA        SIMAO  93018354  6301863631
# 1557    2011-07-20    SHAKILA     ODUBANJO  41408276  6006904500
# 1558    1926-05-13     HABIBA      MALLOTT  21200770  4450373502
#
#               valid_from                                           comments  \
# 0    2021-08-12 11:52:44                                                NaN
# 1    2021-11-08 08:12:05                                                NaN
# 2    2021-12-16 17:18:20                                                NaN
# 3    2022-02-02 18:32:39  She would prefer a massage but she could have ...
# 4    2022-08-03 07:40:47                                                NaN
# ...                  ...                                                ...
# 1554 2021-06-27 01:21:29  She would prefer a massage but she could have ...
# 1555 2021-08-19 05:11:25                                                NaN
# 1556 2021-11-04 05:43:00                                                NaN
# 1557 2022-01-03 12:40:35  She would prefer a massage but she could have ...
# 1558 2021-08-13 13:22:46  She would prefer a massage but she could have ...
#
#       scheduled_datetime  status_change_time  \
# 0    2020-06-17 15:55:00 2021-08-12 09:55:08
# 1    2021-08-22 10:00:00 2021-11-08 08:16:58
# 2    2021-11-10 03:29:00 2021-12-16 17:17:05
# 3    2021-09-30 21:08:00 2022-02-02 17:45:22
# 4    2023-06-14 08:29:00 2022-08-03 08:45:36
# ...                  ...                 ...
# 1554 2021-06-20 05:06:00 2021-06-27 00:20:14
# 1555 2021-05-22 16:46:00 2021-08-19 05:23:44
# 1556 2020-11-16 16:16:00 2021-11-04 06:39:20
# 1557 2021-02-26 04:07:00 2022-01-03 14:39:59
# 1558 2021-10-25 10:00:00 2021-08-13 14:23:04
#
#                                                    name      admission_time  \
# 0                       Inpatient consult to Obstetrics 2020-07-01 18:37:38
# 1                   Inpatient consult to Acute Medicine 2021-08-17 10:10:49
# 2        Inpatient consult to Dietetics (N&D) - Not TPN 2021-11-15 06:22:13
# 3                              Inpatient consult to ENT 2021-09-12 00:46:06
# 4                            Inpatient consult to PERRT 2023-06-21 17:57:02
# ...                                                 ...                 ...
# 1554                         Inpatient consult to PERRT 2021-07-03 19:01:34
# 1555                           Inpatient consult to ENT 2021-05-10 23:44:37
# 1556                Inpatient consult to Acute Medicine 2020-11-30 08:45:10
# 1557  Inpatient Consult to Symptom Control and Palli... 2021-02-21 11:13:10
# 1558            Inpatient consult to Orthopedic Surgery 2021-10-26 05:13:22
#
#      discharge_time               dept_name                 location_string
# 0               NaT      UCH EMERGENCY DEPT         WSU3^W03W BY03^BY03-310
# 1               NaT    UCH T12 NORTH (T12N)   UCLHHOME^UCLHHOME POOL01^HOME
# 2               NaT     MCC G04 ONC SUPPORT       ED^UCH SDEC 23 CH^23-SDEC
# 3               NaT    UCH T14 NORTH TRAUMA    ED^UCHED RAT CHAIR^RAT-CHAIR
# 4               NaT  NHNN Q5 H JACKSON WARD     P02G^UCH P02 ENDO POOL^ENDO
# ...             ...                     ...                             ...
# 1554            NaT    UCH T10 NORTH (T10N)    1020100166^SDEC OTF^SDEC OTF
# 1555            NaT                UCH SDEC          T13S^T13S BY07^BY07-45
# 1556            NaT      UCH EMERGENCY DEPT      1020100166^SDEC 24^24 SDEC
# 1557            NaT  NHNN Q5 H JACKSON WARD  ONCSUP^MCCSUP IN TREAT^HOLDING
# 1558            NaT  UCH T13 NORTH ONCOLOGY          DFNQ^C3DF BY02^BY02-06
#
# [1559 rows x 14 columns]
